# %%
import matplotlib.pyplot as plt
import numpy as np
import re

infile = open("output_hot.txt", "r")

data = infile.read()
#for line in infile:
 #   #line.strip('[]\n')
  #  line=re.sub("\[|\]|\n", "", line)
   # x.append([float(x_i) for x_i in line.split()])

tokens = data.split(']')
tokens[0]

###################################
# data = infile.read().split("]") #
# for x in data:                  #
#     x.strip("\n")               #
###################################
x
#psi_0 = np.histogram(x,bins='auto')
# Out:
# [[0.0, 0.0, -0.03768197, 0.0, 0.0, 0.0],
#  [0.78188558, 0.72489984, -0.38192029, -0.63146834, 0.4217625, 0.0],
#  [0.28725031, 0.0, 0.0, 0.66538753, 0.27037741, 0.0],
#  [0.0, 0.01064389, 0.0, 0.0, 0.8492568, 0.0],
#  [-0.50489027, -0.3111615, 0.0, 0.0, -0.0884479, -0.2987192],
#  [0.0, 0.0, 0.0, 0.42227722, 0.0, 0.55306234],
#  [-0.69877396, 0.54454334, -0.87336852, 0.17121598, 0.0, 0.03325001],
#  [0.0, 0.38269957, 0.0, 0.13797791, -0.67163259, 0.74175925],
#  [1.05252489, -0.48057656, 0.0, 0.0, 0.44691678, 0.0],
#  [0.0, -0.3810669, -0.63955345, -0.58743038, -0.83881002, 0.0],
#  [0.0, -0.32659018, -0.66882814, 0.0, 0.0, 0.43876858],
#  [0.0, 0.0, 0.0, -0.73418085, 0.0, -0.91564801],
#  [0.0, 0.0, 0.54221622, 0.0, 0.0, -0.65240469],
#  [0.0, 0.9001312, 0.0, 0.0, 0.0, -0.42923905],
#  [-0.53755857, 0.36604419, 0.0, -0.52197555, 0.37853696, -0.13619857],
#  [0.25569787, 0.0, 0.60702824, 0.0, 0.0, 0.0],
#  [0.03654539, 0.0, 0.32274655, 0.0, 0.0, 0.15643145],
# ...

# %%
# Out:
# '1,3,5'
